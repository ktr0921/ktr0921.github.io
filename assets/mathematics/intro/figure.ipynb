# %% [markdown]
# # 1_geometrical_view_1.png

# %%
import numpy as np
import matplotlib.pyplot as plt

num = 4
by_05 = np.arange(-num, num + 0.5, 1)
arrow_args = {'width': 0.1, 'length_includes_head': True, 'head_length': 0.3, 'head_width': 0.3}
arrow_args2 = {'width': 0.05, 'length_includes_head': True, 'head_length': 0.15, 'head_width': 0.15}

fig = plt.figure(figsize=(9, 3))

ax = fig.add_subplot(131)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
x = np.arange(-num, num + 0.5, 1)
y1 = (3 + x) / 2
y2 = 3.5 - 1.5 * x
ax.plot(x, y1, 'r', linewidth=2)
ax.plot(x, y2, 'b', linewidth=2)
ax.scatter([1], [2], color='k', zorder=5)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

ax = fig.add_subplot(132)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
ax.arrow(0, 0, 3, 3.5, color='r', zorder=5, **arrow_args)
ax.arrow(0, 0, -1, 1.5, color='b', zorder=5, **arrow_args)
ax.arrow(-1, 1.5, 2, 1, color='g', zorder=5, **arrow_args)
ax.arrow(1, 2.5, 2, 1, color='g', zorder=5, **arrow_args)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

ax = fig.add_subplot(133)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
ax.arrow(0, 0, 1, 2, color='k', zorder=5, **arrow_args)
ax.arrow(1, 2, 2, 1.5, color='purple', zorder=5, **arrow_args)
ax.arrow(0, 0, 3, 3.5, color='r', zorder=5, **arrow_args)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

fig.tight_layout()
plt.savefig('1_geometrical_view_1.png')

# %% [markdown]
# # 1_geometrical_view_2.png

# %%
import numpy as np
import matplotlib.pyplot as plt

num = 4
by_05 = np.arange(-num, num + 0.5, 1)
arrow_args = {'width': 0.1, 'length_includes_head': True, 'head_length': 0.3, 'head_width': 0.3}
arrow_args2 = {'width': 0.05, 'length_includes_head': True, 'head_length': 0.15, 'head_width': 0.15}

fig = plt.figure(figsize=(9, 3))

ax = fig.add_subplot(131)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
x = np.arange(-num, num + 0.5, 1)
y1 = (3 + x) / 2
y2 = (-1.5 - 0.5 * x) / -1
ax.plot(x, y1, 'r', linewidth=2)
ax.plot(x, y2, 'b', linewidth=2)
ax.plot(x, y1, 'r', color='k', zorder=5, linewidth=3)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

ax = fig.add_subplot(132)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
ax.arrow(0, 0, 3, -1.5, color='r', zorder=5, **arrow_args)
ax.arrow(0, 0, -1, 0.5, color='b', zorder=5, **arrow_args)
ax.arrow(0, 0, 2, -1, color='g', zorder=5, **arrow_args)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

ax = fig.add_subplot(133)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
for i in range(9):
    ax.arrow(0, 0, -4 + i, -0.5 + 0.5 * i, color='k', zorder=5, **arrow_args)
    ax.arrow(-4 + i, -0.5 + 0.5 * i, 3 - (-4 + i), -1.5 - (-0.5 + 0.5 * i), color='purple', zorder=5, **arrow_args)
ax.arrow(0, 0, 3, -1.5, color='r', zorder=5, **arrow_args)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

fig.tight_layout()
plt.savefig('1_geometrical_view_2.png')

# %% [markdown]
# # 1_geometrical_view_3.png

# %%
import numpy as np
import matplotlib.pyplot as plt

num = 4
by_05 = np.arange(-num, num + 0.5, 1)
arrow_args = {'width': 0.1, 'length_includes_head': True, 'head_length': 0.3, 'head_width': 0.3}
arrow_args2 = {'width': 0.05, 'length_includes_head': True, 'head_length': 0.15, 'head_width': 0.15}

fig = plt.figure(figsize=(9, 3))

ax = fig.add_subplot(131)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
x = np.arange(-num, num + 0.5, 1)
y1 = (3 + x) / 2
y2 = (0 - 0.5 * x) / -1
ax.plot(x, y1, 'r', linewidth=2)
ax.plot(x, y2, 'b', linewidth=2)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

ax = fig.add_subplot(132)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
ax.arrow(0, 0, 3, 0, color='r', zorder=5, **arrow_args)
ax.arrow(0, 0, -1, 0.5, color='b', zorder=5, **arrow_args)
ax.arrow(0, 0, 2, -1, color='g', zorder=5, **arrow_args)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

ax = fig.add_subplot(133)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
ax.arrow(0, 0, 3, 0, color='r', zorder=5, **arrow_args)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

fig.tight_layout()
plt.savefig('1_geometrical_view_3.png')

# %% [markdown]
# # 1_geometrical_view_4.png

# %%
import numpy as np
import matplotlib.pyplot as plt

num = 4
by_05 = np.arange(-num, num + 0.5, 1)
arrow_args = {'width': 0.1, 'length_includes_head': True, 'head_length': 0.3, 'head_width': 0.3}
arrow_args2 = {'width': 0.05, 'length_includes_head': True, 'head_length': 0.15, 'head_width': 0.15}

fig = plt.figure(figsize=(9, 3))

ax = fig.add_subplot(131)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
x = np.arange(-num, num + 0.5, 1)
ax.plot([1, 1], [-5, 5], 'r', linewidth=2)
ax.plot([-5, 5], [2, 2], 'b', linewidth=2)
ax.scatter([1], [2], color='k', zorder=5)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

ax = fig.add_subplot(132)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
ax.arrow(0, 0, 1, 2, color='r', zorder=5, **arrow_args)
ax.arrow(0, 0, 1, 0, color='b', zorder=5, **arrow_args)
ax.arrow(1, 0, 0, 1, color='g', zorder=5, **arrow_args)
ax.arrow(1, 1, 0, 1, color='g', zorder=5, **arrow_args)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

ax = fig.add_subplot(133)
ax.plot([-5, 5], [0, 0], 'k', [0, 0], [-5, 5], 'k')
ax.arrow(0, 0, 1, 2, color='k', zorder=5, **arrow_args)
ax.arrow(0, 0, 1, 2, color='purple', zorder=5, **arrow_args)
ax.arrow(0, 0, 1, 2, color='r', zorder=5, **arrow_args)
ax.set_xticks(by_05)
ax.set_yticks(by_05)
ax.set_xlim([-num, num])
ax.set_ylim([-num, num])
ax.grid()

fig.tight_layout()
plt.savefig('1_geometrical_view_4.png')
